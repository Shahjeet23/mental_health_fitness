# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\shahj\Downloads\survey.csv")

# %%
data.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  1259 non-null   object
#  1   Age                        1259 non-null   int64
#  2   Gender                     1259 non-null   object
#  3   Country                    1259 non-null   object
#  4   state                      744 non-null    object
#  5   self_employed              1241 non-null   object
#  6   family_history             1259 non-null   object
#  7   treatment                  1259 non-null   object
#  8   work_interfere             995 non-null    object
#  9   no_employees               1259 non-null   object
#  10  remote_work                1259 non-null   object
#  11  tech_company               1259 non-null   object
#  12  benefits                   1259 non-null   object
# ...

# %%
df=data.copy()

# %%
df
# Out:
#                 Timestamp  Age  Gender         Country state self_employed  \
# 0     2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1     2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2     2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3     2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4     2014-08-27 11:30:22   31    Male   United States    TX           NaN
# ...                   ...  ...     ...             ...   ...           ...
# 1254  2015-09-12 11:17:21   26    male  United Kingdom   NaN            No
# 1255  2015-09-26 01:07:35   32    Male   United States    IL            No
# 1256  2015-11-07 12:36:58   34    male   United States    CA            No
# 1257  2015-11-30 21:25:06   46       f   United States    NC            No
# 1258  2016-02-01 23:04:31   25    Male   United States    IL            No
#
#      family_history treatment work_interfere    no_employees  ...  \
# ...

# %%
df.shape,df.size
# Out:
# ((1259, 27), 33993)

# %%
df['Country'].value_counts().plot(kind="bar",figsize=(10,8))
# Out:
# <AxesSubplot:>

# %%
df.drop(['comments'],axis=1,inplace=True)

# %%
df.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...   anonymity  \
# 0             No       Yes          Often            6-25  ...         Yes
# 1             No        No         Rarely  More than 1000  ...  Don't know
# 2             No        No         Rarely            6-25  ...  Don't know
# 3            Yes       Yes          Often          26-100  ...          No
# 4             No        No          Never         100-500  ...  Don't know
#
#                 leave mental_health_consequence phys_health_consequence  \
# ...

# %%
Age=list(data["Age"])

# %%
df.drop(['Age'],axis=1,inplace=True)

# %%
df.insert(0,"Age",Age)

# %%
df
# Out:
#       Age            Timestamp  Gender         Country state self_employed  \
# 0      37  2014-08-27 11:29:31  Female   United States    IL           NaN
# 1      44  2014-08-27 11:29:37       M   United States    IN           NaN
# 2      32  2014-08-27 11:29:44    Male          Canada   NaN           NaN
# 3      31  2014-08-27 11:29:46    Male  United Kingdom   NaN           NaN
# 4      31  2014-08-27 11:30:22    Male   United States    TX           NaN
# ...   ...                  ...     ...             ...   ...           ...
# 1254   26  2015-09-12 11:17:21    male  United Kingdom   NaN            No
# 1255   32  2015-09-26 01:07:35    Male   United States    IL            No
# 1256   34  2015-11-07 12:36:58    male   United States    CA            No
# 1257   46  2015-11-30 21:25:06       f   United States    NC            No
# 1258   25  2016-02-01 23:04:31    Male   United States    IL            No
#
# ...

# %%
df.isnull().sum()
# Out:
# Age                            0
# Timestamp                      0
# Gender                         0
# Country                        0
# state                        515
# self_employed                 18
# family_history                 0
# treatment                      0
# work_interfere               264
# no_employees                   0
# remote_work                    0
# tech_company                   0
# benefits                       0
# care_options                   0
# wellness_program               0
# seek_help                      0
# anonymity                      0
# leave                          0
# mental_health_consequence      0
# phys_health_consequence        0
# coworkers                      0
# supervisor                     0
# mental_health_interview        0
# phys_health_interview          0
# mental_vs_physical             0
# obs_consequence                0
# dtype: int64

# %%
df['self_employed'].value_counts()
# Out:
# No     1095
# Yes     146
# Name: self_employed, dtype: int64

# %%
df['self_employed'].fillna('No',inplace=True)

# %%
df.head()
# Out:
#    Age            Timestamp  Gender         Country state self_employed  \
# 0   37  2014-08-27 11:29:31  Female   United States    IL            No
# 1   44  2014-08-27 11:29:37       M   United States    IN            No
# 2   32  2014-08-27 11:29:44    Male          Canada   NaN            No
# 3   31  2014-08-27 11:29:46    Male  United Kingdom   NaN            No
# 4   31  2014-08-27 11:30:22    Male   United States    TX            No
#
#   family_history treatment work_interfere    no_employees  ...   anonymity  \
# 0             No       Yes          Often            6-25  ...         Yes
# 1             No        No         Rarely  More than 1000  ...  Don't know
# 2             No        No         Rarely            6-25  ...  Don't know
# 3            Yes       Yes          Often          26-100  ...          No
# 4             No        No          Never         100-500  ...  Don't know
#
#                 leave mental_health_consequence phys_health_consequence  \
# ...

# %%
df['work_interfere'].value_counts()
# Out:
# Sometimes    465
# Never        213
# Rarely       173
# Often        144
# Name: work_interfere, dtype: int64

# %%
df['work_interfere'].fillna('N/A',inplace=True)

# %%
df['Age'].value_counts().plot(kind="bar",figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
df.drop(df[(df['Age']<18) |(df['Age']>60)].index,inplace=True)

# %%
df['Age'].value_counts()
# Out:
# 29    85
# 32    82
# 26    75
# 27    71
# 33    70
# 28    68
# 31    67
# 34    65
# 30    63
# 25    61
# 35    55
# 23    51
# 24    46
# 37    43
# 38    39
# 36    37
# 39    33
# 40    33
# 43    28
# 22    21
# 41    21
# 42    20
# 21    16
# 46    12
# 45    12
# 44    11
# 19     9
# 18     7
# 50     6
# 48     6
# 20     6
# 51     5
# 56     4
# 49     4
# 54     3
# 55     3
# 57     3
# 60     2
# 47     2
# 58     1
# 53     1
# Name: Age, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Male                                              611
# male                                              203
# Female                                            120
# M                                                 115
# female                                             62
# F                                                  38
# m                                                  34
# f                                                  15
# Make                                                4
# Woman                                               3
# Male                                                3
# Female                                              2
# Cis Male                                            2
# Man                                                 2
# Female (trans)                                      2
# Malr                                                1
# Trans woman                                         1
# ...

# %%
# df['Gender'].replace(['Male','male','M','m','make','Male','Cis Male',''])
cl=df['Gender'].explode().tolist()
cl=set(cl)
cl=list(cl)
cl
# Out:
# ['Enby',
#  'cis male',
#  'Man',
#  'something kinda male?',
#  'femail',
#  'Woman',
#  'queer/she/they',
#  'Make',
#  'male leaning androgynous',
#  'Male',
#  'Male ',
#  'ostensibly male, unsure what that really means',
#  'male',
#  'fluid',
#  'Male-ish',
#  'Cis Male',
#  'Guy (-ish) ^_^',
#  'Mail',
#  'Cis Female',
#  'F',
#  'maile',
#  'Cis Man',
#  'Trans-female',
#  'woman',
#  'msle',
#  'Female (trans)',
#  'Mal',
#  'Trans woman',
#  'queer',
#  'non-binary',
#  'Female (cis)',
#  'Female',
#  'Agender',
#  'm',
#  'cis-female/femme',
#  'f',
#  'Malr',
#  'female',
#  'Neuter',
#  'Femake',
#  'M',
#  'Male (CIS)',
#  'Nah',
#  'Androgyne',
#  'Genderqueer',
#  'Female ']

# %%
df['Gender'].replace(['Make',
 
 'm',
 
 'Male-ish',
 
 
 
 
 'Cis Male',
 'cis male',
 'Male',
 
 'Cis Man',
 'Male ',
 
 
 'Malr',
 'male',
 
 'M',
 
 'msle',
 'Mail',
 'Mal',
 
 
 'Male (CIS)',
 'Man',
 
 
 
 
 'male leaning androgynous',
 
 'maile',
 ],'Male',inplace=True)
df['Gender'].replace([
 'Trans woman',
 
 'cis-female/femme',
 
 'Femake',
 'Female (cis)',
 'Cis Female',
 
 
 'femail',
 
 
 'F',
 'f',
 'Female',
 'woman',
 
 'Woman',
 
 'female',
 'Female ',
 ],"Female",inplace=True)

# %%
set_l3=set(['Female (trans)',
 'Neuter',
 'Make',
 'Trans-female',
 'female',
 'cis male',
 'Male-ish',
 'Female',
 'Female (cis)',
 'maile',
 'Female ',
 'msle',
 'woman',
 'Enby',
 'Androgyne',
 'Cis Female',
 'male leaning androgynous',
 'Genderqueer',
 'F',
 'Cis Male',
 'Male (CIS)',
 'Femake',
 'Malr',
 'Man',
 'Guy (-ish) ^_^',
 'ostensibly male, unsure what that really means',
 'Mal',
 'Nah',
 'Trans woman',
 'm',
 'male',
 'queer',
 'non-binary',
 'Woman',
 'Male',
 'Mail',
 'queer/she/they',
 'f',
 'M',
 'Agender',
 'cis-female/femme',
 'Male ',
 'femail',
 'Cis Man',
 'fluid',
 'something kinda male?'])
set_l1=set(['Make',
 
 'm',
 
 'Male-ish',
 
 
 
 
 'Cis Male',
 'cis male',
 'Male',
 
 'Cis Man',
 'Male ',
 
 
 'Malr',
 'male',
 
 'M',
 
 'msle',
 'Mail',
 'Mal',
 
 
 'Male (CIS)',
 'Man',
 
 
 
 
 'male leaning androgynous',
 
 'maile',
 ])

# %%
set_l2=set([
 'Trans woman',
 
 'cis-female/femme',
 
 'Femake',
 'Female (cis)',
 'Cis Female',
 
 
 'femail',
 
 
 'F',
 'f',
 'Female',
 'woman',
 
 'Woman',
 
 'female',
 'Female ',
 ])
           
set_l3 = set_l3.symmetric_difference(set_l2)

set_l3 = set_l3.symmetric_difference(set_l1)
list(set_l3)
# Out:
# ['Enby',
#  'queer',
#  'non-binary',
#  'something kinda male?',
#  'queer/she/they',
#  'ostensibly male, unsure what that really means',
#  'Agender',
#  'fluid',
#  'Guy (-ish) ^_^',
#  'Genderqueer',
#  'Neuter',
#  'Trans-female',
#  'Female (trans)',
#  'Nah',
#  'Androgyne']

# %%
df['Gender'].replace(['Female (trans)',
 'Neuter',
 'Guy (-ish) ^_^',
 'ostensibly male, unsure what that really means',
 'Trans-female',
 'Nah',
 'queer',
 'non-binary',
 'queer/she/they',
 'Agender',
 'Enby',
 'Androgyne',
 'Genderqueer',
 'fluid',
 'something kinda male?'],"Non-binary",inplace=True)

# %%
df['Gender'].value_counts()
# Out:
# Male          984
# Female        247
# Non-binary     16
# Name: Gender, dtype: int64

# %%
sns.distplot(df["Age"])
plt.title("Distribution age")
plt.xlabel("Age")
# Out:
# C:\Users\shahj\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Age')

# %%
sns.countplot(df['family_history'],hue=df["treatment"])
# Out:
# C:\Users\shahj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='family_history', ylabel='count'>

# %%
sns.countplot(df['self_employed'],hue=df["treatment"])
# Out:
# C:\Users\shahj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='self_employed', ylabel='count'>

# %%
sns.countplot(df['work_interfere'],hue=df["treatment"])
# Out:
# C:\Users\shahj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='work_interfere', ylabel='count'>

# %%
sns.countplot(df['remote_work'],hue=df["treatment"])
plt.title("work type")
# Out:
# C:\Users\shahj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'work type')

# %%
sns.countplot(df['tech_company'],hue=df['treatment'])
# Out:
# C:\Users\shahj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='tech_company', ylabel='count'>

# %%
sns.countplot(df['care_options'],hue=df['treatment'])
plt.title("care_options")
# Out:
# C:\Users\shahj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'care_options')

# %%
sns.countplot(df['mental_vs_physical'],hue=df['treatment'])
plt.title('importance of mental and physical health')
# Out:
# C:\Users\shahj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'importance of mental and physical health')

# %%
sns.countplot(df['wellness_program'],hue=df['treatment'])
plt.title("wellness program")
# Out:
# C:\Users\shahj\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'wellness program')

# %%
df.describe(include='all')
# Out:
#                 Age            Timestamp Gender        Country state  \
# count   1247.000000                 1247   1247           1247   735
# unique          NaN                 1235      3             46    45
# top             NaN  2014-08-27 12:44:51   Male  United States    CA
# freq            NaN                    2    984            743   137
# mean      31.971131                  NaN    NaN            NaN   NaN
# std        7.052598                  NaN    NaN            NaN   NaN
# min       18.000000                  NaN    NaN            NaN   NaN
# 25%       27.000000                  NaN    NaN            NaN   NaN
# 50%       31.000000                  NaN    NaN            NaN   NaN
# 75%       36.000000                  NaN    NaN            NaN   NaN
# max       60.000000                  NaN    NaN            NaN   NaN
#
#        self_employed family_history treatment work_interfere no_employees  \
# ...

# %%
# ct= ColumnTransformer([('oe',OrdinalEncoder(),['Gender','self_employed','family_history','work_interfere','no_employees','remote_work','tech_company','benefits','care_options','wellness_program'
#                                               'seek_help','anonymity','leave','mental_health_consequence','phys_health_consequence','coworkers','supervisor','mental_health_interview','phys_health_interview','mental_vs_physical','obs_consequence'])],remainder='passthrough')

# %%
# X=ct.fit_transform(x)
# X

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
#Make the dataset include all the columns we need to change their dtypes
columns_to_encode = ['Gender', 'Country', 'self_employed','family_history', 'treatment', 'work_interfere','no_employees',
                             'remote_work', 'tech_company','benefits','care_options', 'wellness_program',
                             'seek_help', 'anonymity', 'leave', 'mental_health_consequence', 'phys_health_consequence',
                             'coworkers', 'supervisor', 'mental_health_interview','phys_health_interview',
                             'mental_vs_physical', 'obs_consequence']
#Write a Loop for fitting LabelEncoder on columns_to_encode
for columns in columns_to_encode:
    df[columns] = le.fit_transform(df[columns])
    
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1247 entries, 0 to 1258
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        1247 non-null   int64
#  1   Timestamp                  1247 non-null   object
#  2   Gender                     1247 non-null   int32
#  3   Country                    1247 non-null   int32
#  4   state                      735 non-null    object
#  5   self_employed              1247 non-null   int32
#  6   family_history             1247 non-null   int32
#  7   treatment                  1247 non-null   int32
#  8   work_interfere             1247 non-null   int32
#  9   no_employees               1247 non-null   int32
#  10  remote_work                1247 non-null   int32
#  11  tech_company               1247 non-null   int32
#  12  benefits                   1247 non-null   int32
# ...

# %%
x=df.drop(['treatment'],axis=1)
y=df['treatment']
y
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 1254    1
# 1255    1
# 1256    1
# 1257    0
# 1258    1
# Name: treatment, Length: 1247, dtype: int32

# %%
from sklearn.preprocessing import MaxAbsScaler, StandardScaler

df['Age'] = MaxAbsScaler().fit_transform(df[['Age']])
df['Country'] = StandardScaler().fit_transform(df[['Country']])
df['work_interfere'] = StandardScaler().fit_transform(df[['work_interfere']])
df['no_employees'] = StandardScaler().fit_transform(df[['no_employees']])
df['leave'] = StandardScaler().fit_transform(df[['leave']])

df.describe()
# Out:
#                Age       Gender       Country  self_employed  family_history  \
# count  1247.000000  1247.000000  1.247000e+03    1247.000000     1247.000000
# mean      0.532852     0.814755  2.704778e-16       0.112269        0.391339
# std       0.117543     0.420395  1.000401e+00       0.315824        0.488246
# min       0.300000     0.000000 -2.771675e+00       0.000000        0.000000
# 25%       0.450000     1.000000  3.179213e-01       0.000000        0.000000
# 50%       0.516667     1.000000  5.439893e-01       0.000000        0.000000
# 75%       0.600000     1.000000  5.439893e-01       0.000000        1.000000
# max       1.000000     2.000000  6.193453e-01       1.000000        1.000000
#
#          treatment  work_interfere  no_employees  remote_work  tech_company  \
# count  1247.000000    1.247000e+03  1.247000e+03  1247.000000   1247.000000
# mean      0.505213    3.881774e-17  3.253212e-16     0.295108      0.820369
# ...

# %%
df
x=df.drop(['Timestamp','state','treatment'],axis=1)
y=df['treatment']
x.info()
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1247 entries, 0 to 1258
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        1247 non-null   float64
#  1   Gender                     1247 non-null   int32
#  2   Country                    1247 non-null   float64
#  3   self_employed              1247 non-null   int32
#  4   family_history             1247 non-null   int32
#  5   work_interfere             1247 non-null   float64
#  6   no_employees               1247 non-null   float64
#  7   remote_work                1247 non-null   int32
#  8   tech_company               1247 non-null   int32
#  9   benefits                   1247 non-null   int32
#  10  care_options               1247 non-null   int32
#  11  wellness_program           1247 non-null   int32
#  12  seek_help                  1247 non-null   int32
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y)

# %%
print(x_train.shape,x_test.shape)
# Out:
# (935, 23) (312, 23)

# %%
print(y_train.shape,y_test.shape)
# Out:
# (935,) (312,)

# %%
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier 
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.linear_model import LogisticRegression

from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.tree import DecisionTreeClassifier as DT
from sklearn.metrics import accuracy_score, roc_curve ,confusion_matrix,classification_report ,auc

# %%
model_dict={}
model_dict['logistic'] = LogisticRegression(random_state=49)
model_dict['knn'] = KNN()
model_dict['ada '] = AdaBoostClassifier(random_state=49)
model_dict['svc']= SVC(random_state=49)
model_dict['dt ']= DT(random_state=49)

# %%
def model_test(x_train,y_train,x_test,y_test,model,model_name):
    model_name.fit(x_train,y_train)
    y_pred=model_name.predict(x_test)
    accuracy=accuracy_score(y_test,y_pred)
    print(f"==================================={model_name}================================")
    print(f"score is a {accuracy}")
    print()

# %%
for model , model_name in model_dict.items():
    model_test(x_train,y_train,x_test,y_test,model,model_name)
#      print(model ,model_name)
# Out:
# ===================================LogisticRegression(random_state=49)================================
# score is a 0.8365384615384616
#
# ===================================KNeighborsClassifier()================================
# score is a 0.7564102564102564
#
# ===================================AdaBoostClassifier(random_state=49)================================
# score is a 0.8333333333333334
#
# ===================================SVC(random_state=49)================================
# score is a 0.8269230769230769
#
# ===================================DecisionTreeClassifier(random_state=49)================================
# score is a 0.7371794871794872
# ...

# %%
rfc = RandomForestClassifier(random_state=49)
rfc.fit(x_train,y_train)
pred=rfc.predict(x_test)
print('accuracy of random',accuracy_score(y_test,pred))
# Out:
# accuracy of random 0.8205128205128205

# %%
ada = AdaBoostClassifier(random_state=99)
ada.fit(x_train,y_train)
pred=ada.predict(x_test)
print('accuracy of adaboost=',accuracy_score(y_test,pred))
# Out:
# accuracy of adaboost= 0.8333333333333334

# %%
matrix= confusion_matrix(y_test,pred)
sns.heatmap(matrix/np.sum(matrix),annot=True,fmt='2%')
plt.title('confusion matrix of adaboost classifier')
plt.xlabel('predicted')
plt.ylabel('actual')
# Out:
# Text(50.722222222222214, 0.5, 'actual')
